# %% [markdown]
# ## AoC day 1a, 2023
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
# ```
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# ```
#
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.
#
# Consider your entire calibration document. What is the sum of all of the calibration values?

# %%
samp = """
1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet
"""

# %%
print(samp.splitlines())
# Out:
# ['', '1abc2', 'pqr3stu8vwx', 'a1b2c3d4e5f', 'treb7uchet']

# %% [markdown]
# **AI Prompt**
#
# how do i modify to not include empty space?

# %% [markdown]
# **AI Response**
#
# To remove empty lines when using splitlines(), you can add strip() to remove whitespace. Try this:
#
# ```python
# print([line for line in samp.splitlines() if line.strip()])
# ```
#
# Would you like me to explain how this works?

# %%
samp.splitlines?
# Out:
# Signature: samp.splitlines(keepends=False)
# Docstring:
# Return a list of the lines in the string, breaking at line boundaries.
#
# Line breaks are not included in the resulting list unless keepends is given and
# true.
# Type:      builtin_function_or_method

# %%
first = None
last = None
for l in samp.splitlines()[1]:
    if l.isdigit():
        if not first:
            first = l
        last = l
print(first, last)
# Out:
# 1 2

# %%
first = None
last = None
for l in samp.splitlines()[1]:
    if l.isdigit():
        if not first:
            first = l
        last = l
print(first + last)
# Out:
# 12

# %%
def calibrate(w):
    first = None
    last = None
    for l in samp.splitlines()[1]:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return first + last
calibrate[samp.splitlines()[1]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8             last = l
#       9     return first + last
# ---> 10 calibrate[samp.splitlines()[1]]
#
# TypeError: 'function' object is not subscriptable

# %%
def calibrate(w):
    first = None
    last = None
    for l in samp.splitlines()[1]:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return first + last
calibrate(samp.splitlines()[1])

# %% [markdown]
# **AI Prompt**
#
# any improvements you might make to the previous code?

# %% [markdown]
# **AI Response**
#
# A few potential improvements to consider:
#
# 1. The current code only processes the second line (index [1]) because of `splitlines()[1]`. You probably want to process all lines.
# 2. It would be good to store the results for all lines.
# 3. We could make it more efficient by using a single loop.
#
# Would you like to try making these improvements yourself, or would you like me to show you an example?

# %%
def calibrate(w):
    first = None
    last = None
    for l in samp.splitlines()[1]:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return first + last
sum([calibrate(w) for w in samp.splitlines()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8             last = l
#       9     return first + last
# ---> 10 sum([calibrate(w) for w in samp.splitlines()])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def calibrate(w):
    first = None
    last = None
    for l in samp.splitlines()[1]:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return first + last
sum([calibrate(int(w)) for w in samp.splitlines()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8             last = l
#       9     return first + last
# ---> 10 sum([calibrate(int(w)) for w in samp.splitlines()])
#
# Cell In[1], line 10, in <listcomp>(.0)
#       8             last = l
#       9     return first + last
# ---> 10 sum([calibrate(int(w)) for w in samp.splitlines()])
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def calibrate(w):
    first = None
    last = None
    for l in w:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return first + last
sum([calibrate(int(w)) for w in samp.splitlines()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8             last = l
#       9     return first + last
# ---> 10 sum([calibrate(int(w)) for w in samp.splitlines()])
#
# Cell In[1], line 10, in <listcomp>(.0)
#       8             last = l
#       9     return first + last
# ---> 10 sum([calibrate(int(w)) for w in samp.splitlines()])
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# **AI Prompt**
#
# how to fix the bug above

# %% [markdown]
# **AI Response**
#
# There are a few issues to fix:
#
# 1. We need to skip empty lines
# 2. We shouldn't try to convert the whole line to int - we just want to find digits in it
# 3. We need to convert the final result to int before summing
#
# Try modifying the code like this:
#
# ```python
# def calibrate(w):
#     first = None
#     last = None
#     for l in w:
#         if l.isdigit():
#             if not first:
#                 first = l
#             last = l
#     return int(first + last)
#
# sum(calibrate(w) for w in samp.splitlines() if w.strip())
# ```
#
# Would you like me to explain what each change does?

# %%
def calibrate(w):
    first = None
    last = None
    for l in w:
        if l.isdigit():
            if not first:
                first = l
            last = l
    return int(first + last)

sum(calibrate(w) for w in samp.splitlines() if w.strip())

# %% [markdown]
# **AI Prompt**
#
# how to use aocd for the full data?

# %% [markdown]
# **AI Response**
#
# You can use the `aocd` library to get your puzzle input. Here's how to get data for day 1 of 2023:
#
# ```python
# from aocd import get_data
# data = get_data(day=1, year=2023)
# ```
#
# Would you like to try adapting your current code to work with this data? Make sure you've logged in with your Advent of Code credentials first.

# %%
from aocd import get_data
data = get_data(day=1, year=2023)
sum(calibrate(w) for w in data.splitlines() if w.strip())
